# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    season      date  league_id                league                Team 1  \
# 0    2019  01/03/19       1979  Chinese Super League       Shandong Luneng
# 1    2019  01/03/19       1979  Chinese Super League    Shanghai Greenland
# 2    2019  01/03/19       1979  Chinese Super League  Guangzhou Evergrande
# 3    2019  01/03/19       1979  Chinese Super League            Wuhan Zall
# 4    2019  01/03/19       1979  Chinese Super League       Chongqing Lifan
#
#                Team2   SPI1   SPI2  proj_score1  proj_score2  ...  \
# 0      Guizhou Renhe  48.22  37.83         1.75         0.84  ...
# 1      Shanghai SIPG  39.81  60.08         1.22         1.89  ...
# 2  Tianjin Quanujian  65.59  39.99         2.58         0.62  ...
# 3      Beijing Guoan  32.25  54.82         1.10         1.79  ...
# 4       Guangzhou RF  38.24  40.45         1.57         1.24  ...
#
#    importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  \
# ...

# %%
train.shape
# Out:
# (7443, 21)

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    season      date  league_id league                    Team 1  \
# 0    2021  14/12/21       2411    BPL                   Arsenal
# 1    2021  14/12/21       2411    BPL  Brighton and Hove Albion
# 2    2021  14/12/21       2411    BPL              Norwich City
# 3    2021  14/12/21       2411    BPL            Leicester City
# 4    2021  14/12/21       2411    BPL                 Brentford
#
#                Team2   SPI1   SPI2  proj_score1  proj_score2  importance1  \
# 0    West Ham United  79.65  74.06         1.67         1.19          NaN
# 1      Wolverhampton  74.19  71.14         1.35         0.98          NaN
# 2        Aston Villa  60.67  71.45         1.18         1.49          NaN
# 3  Tottenham Hotspur  76.88  79.06         1.52         1.44          NaN
# 4  Manchester United  63.53  85.58         0.95         1.92          NaN
#
#    importance2  score1  score2  xg1  xg2  nsxg1  nsxg2  adj_score1  adj_score2
# ...

# %%
test.shape
# Out:
# (4008, 20)

# %%
train['Outcome'].value_counts()
# Out:
# 1    5070
# 0    2373
# Name: Outcome, dtype: int64

# %%
train[train['Outcome'] == 0].head()
# Out:
#     season      date  league_id                league              Team 1  \
# 1     2019  01/03/19       1979  Chinese Super League  Shanghai Greenland
# 3     2019  01/03/19       1979  Chinese Super League          Wuhan Zall
# 6     2019  02/03/19       1979  Chinese Super League        Henan Jianye
# 9     2019  08/03/19       1979  Chinese Super League     Chongqing Lifan
# 17    2019  30/03/19       1979  Chinese Super League       Guizhou Renhe
#
#             Team2   SPI1   SPI2  proj_score1  proj_score2  ...  importance2  \
# 1   Shanghai SIPG  39.81  60.08         1.22         1.89  ...         63.4
# 3   Beijing Guoan  32.25  54.82         1.10         1.79  ...         58.9
# 6   Dalian Aerbin  35.18  45.83         1.22         1.29  ...         41.0
# 9   Beijing Guoan  37.51  54.42         1.19         1.67  ...         64.3
# 17  Beijing Guoan  37.13  57.12         1.05         1.58  ...         63.0
#
# ...

# %%
train[train['Outcome'] == 1].head()
# Out:
#    season      date  league_id                league                Team 1  \
# 0    2019  01/03/19       1979  Chinese Super League       Shandong Luneng
# 2    2019  01/03/19       1979  Chinese Super League  Guangzhou Evergrande
# 4    2019  01/03/19       1979  Chinese Super League       Chongqing Lifan
# 5    2019  02/03/19       1979  Chinese Super League           Shenzhen FC
# 7    2019  03/03/19       1979  Chinese Super League     Jiangsu Suning FC
#
#                     Team2   SPI1   SPI2  proj_score1  proj_score2  ...  \
# 0           Guizhou Renhe  48.22  37.83         1.75         0.84  ...
# 2       Tianjin Quanujian  65.59  39.99         2.58         0.62  ...
# 4            Guangzhou RF  38.24  40.45         1.57         1.24  ...
# 5  Hebei China Fortune FC  31.99  38.75         1.41         1.25  ...
# 7            Tianjin Teda  51.59  36.92         1.92         0.78  ...
#
#    importance2  score1  score2   xg1   xg2  nsxg1  nsxg2  adj_score1  \
# ...

# %%
train['proj_difference'] = train['proj_score1'] - train['proj_score2']

# %%
test['proj_difference'] = test['proj_score1'] - test['proj_score2']

# %%
train[train['Outcome'] == 0]['proj_difference']
# Out:
# 1      -0.67
# 3      -0.69
# 6      -0.07
# 9      -0.48
# 17     -0.53
#         ...
# 7434   -0.13
# 7435   -0.89
# 7437   -0.03
# 7440   -0.45
# 7441   -0.24
# Name: proj_difference, Length: 2373, dtype: float64

# %%
train[train['Outcome'] == 1]['proj_difference']
# Out:
# 0       0.91
# 2       1.96
# 4       0.33
# 5       0.16
# 7       1.14
#         ...
# 7433    0.85
# 7436    0.59
# 7438    0.20
# 7439    0.23
# 7442    0.82
# Name: proj_difference, Length: 5070, dtype: float64

# %%
a = pd.DataFrame({'Outcome' : test.apply(lambda x:0 if x.proj_difference < 0 else 1, axis = 1)})
a.head()
# Out:
#    Outcome
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0

# %%
a.to_csv('Solution1.csv', index = False)
