# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor, GradientBoostingRegressor, BaggingRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split, KFold, GridSearchCV

# %%
train = pd.read_csv('Train.csv')
train.head()
# Out:
#    Holiday  Temperature  Rainfall_last_hour  Snowfall_last_hour  Cloud_Cover  \
# 0      NaN       289.28                 0.0                 0.0           40
# 1      NaN       290.26                 0.0                 0.0           75
# 2      NaN       290.28                 0.0                 0.0           90
# 3      NaN       290.33                 0.0                 0.0           90
# 4      NaN       292.14                 0.0                 0.0           75
#
#         Weather         Weather_Desc       TimeStamp      Date  Traffic_Vol
# 0  Cloudy skies  Partly cloudy skies   02/10/08 9:00  02/10/08         5555
# 1  Cloudy skies    Fragmented clouds  02/10/08 10:00  02/10/08         4525
# 2  Cloudy skies     Full cloud cover  02/10/08 11:00  02/10/08         4772
# 3  Cloudy skies     Full cloud cover  02/10/08 12:00  02/10/08         5031
# 4  Cloudy skies    Fragmented clouds  02/10/08 13:00  02/10/08         4928

# %%
train.shape
# Out:
# (38373, 10)

# %%
train.isnull().sum()
# Out:
# Holiday               38323
# Temperature               0
# Rainfall_last_hour        0
# Snowfall_last_hour        0
# Cloud_Cover               0
# Weather                   0
# Weather_Desc              0
# TimeStamp                 0
# Date                      0
# Traffic_Vol               0
# dtype: int64

# %%
train.duplicated().sum()
# Out:
# 0

# %%
test = pd.read_csv('Test.csv')
test.head()
# Out:
#    Holiday  Temperature  Rainfall_last_hour  Snowfall_last_hour  Cloud_Cover  \
# 0      NaN       297.65                 0.0                   0            1
# 1      NaN       297.45                 0.0                   0            1
# 2      NaN       296.75                 0.0                   0            1
# 3      NaN       296.42                 0.0                   0            1
# 4      NaN       295.56                 0.0                   0           40
#
#        Weather Weather_Desc      TimeStamp      Date  Traffic_Vol
# 0  Clear skies  Clear skies  01/07/14 0:00  01/07/14          NaN
# 1  Clear skies  Clear skies  01/07/14 1:00  01/07/14          NaN
# 2     Rainfall    Soft rain  01/07/14 2:00  01/07/14          NaN
# 3     Rainfall  Steady rain  01/07/14 3:00  01/07/14          NaN
# 4     Rainfall    Soft rain  01/07/14 4:00  01/07/14          NaN

# %%
test.shape
# Out:
# (2208, 10)

# %%
test.isnull().sum()
# Out:
# Holiday               2205
# Temperature              0
# Rainfall_last_hour       0
# Snowfall_last_hour       0
# Cloud_Cover              0
# Weather                  0
# Weather_Desc             0
# TimeStamp                0
# Date                     0
# Traffic_Vol           2208
# dtype: int64

# %%
test.duplicated().sum()
# Out:
# 0

# %%
train.tail()
# Out:
#        Holiday  Temperature  Rainfall_last_hour  Snowfall_last_hour  \
# 38368      NaN       301.38                 0.0                 0.0
# 38369      NaN       300.28                 0.0                 0.0
# 38370      NaN       300.48                 0.0                 0.0
# 38371      NaN       299.08                 0.0                 0.0
# 38372      NaN       298.22                 0.0                 0.0
#
#        Cloud_Cover       Weather         Weather_Desc       TimeStamp  \
# 38368           90  Cloudy skies     Full cloud cover  30/06/14 19:00
# 38369           91  Cloudy skies     Full cloud cover  30/06/14 20:00
# 38370           91  Cloudy skies     Full cloud cover  30/06/14 21:00
# 38371           75  Cloudy skies    Fragmented clouds  30/06/14 22:00
# 38372           40  Cloudy skies  Partly cloudy skies  30/06/14 23:00
#
#            Date  Traffic_Vol
# 38368  30/06/14         3252
# 38369  30/06/14         2941
# 38370  30/06/14         2703
# 38371  30/06/14         2762
# 38372  30/06/14         2023

# %%
combined = pd.concat([train, test], axis = 0)
combined.head()
# Out:
#    Holiday  Temperature  Rainfall_last_hour  Snowfall_last_hour  Cloud_Cover  \
# 0      NaN       289.28                 0.0                 0.0           40
# 1      NaN       290.26                 0.0                 0.0           75
# 2      NaN       290.28                 0.0                 0.0           90
# 3      NaN       290.33                 0.0                 0.0           90
# 4      NaN       292.14                 0.0                 0.0           75
#
#         Weather         Weather_Desc       TimeStamp      Date  Traffic_Vol
# 0  Cloudy skies  Partly cloudy skies   02/10/08 9:00  02/10/08       5555.0
# 1  Cloudy skies    Fragmented clouds  02/10/08 10:00  02/10/08       4525.0
# 2  Cloudy skies     Full cloud cover  02/10/08 11:00  02/10/08       4772.0
# 3  Cloudy skies     Full cloud cover  02/10/08 12:00  02/10/08       5031.0
# 4  Cloudy skies    Fragmented clouds  02/10/08 13:00  02/10/08       4928.0

# %%
combined.shape
# Out:
# (40581, 10)

# %%
combined[combined['Holiday'].notna()]
# Out:
#        Holiday  Temperature  Rainfall_last_hour  Snowfall_last_hour  \
# 126        1.0      274.080                0.00                 0.0
# 926        1.0      288.620                0.00                 0.0
# 1164       1.0      279.240                0.00                 0.0
# 1938       1.0      265.100                0.00                 0.0
# 2103       1.0      263.890                0.00                 0.0
# 3066       1.0      259.160                0.00                 0.0
# 5236       1.0      287.170                0.00                 0.0
# 6075       1.0      291.080                0.00                 0.0
# 7178       1.0      297.820                0.00                 0.0
# 7340       1.0      289.780                0.00                 0.0
# 7966       1.0      278.520                0.00                 0.0
# 8236       1.0      275.840                0.00                 0.0
# 8627       1.0      268.640                0.00                 0.0
# 9238       1.0      260.570                0.25                 0.0
# 9397       1.0      250.640                0.00                 0.0
# 9821       1.0      272.590                0.00                 0.0
# 10484      1.0      267.540                0.00                 0.0
# 12706      1.0      295.110                0.00                 0.0
# 14094      1.0      289.900                0.00                 0.0
# 15406      1.0      288.670                0.00                 0.0
# 15643      1.0      295.420                0.00                 0.0
# 16395      1.0      293.920                0.00                 0.0
# 16788      1.0      284.150                0.00                 0.0
# 16986      1.0      277.620                0.00                 0.0
# 17366      1.0      269.390                0.00                 0.0
# 17491      1.0      266.240                0.00                 0.0
# 18231      1.0      265.750                0.00                 0.0
# 20212      1.0      289.280                0.00                 0.0
# 21039      1.0      290.250                0.00                 0.0
# 22280      1.0      291.520                0.00                 0.0
# 22541      1.0      293.770                1.62                 0.0
# 23372      1.0      282.541                0.00                 0.0
# 24123      1.0      282.860                0.00                 0.0
# 24435      1.0      274.540                0.00                 0.0
# 25185      1.0      276.680                0.00                 0.0
# 25353      1.0      271.520                0.00                 0.0
# 25689      1.0      266.780                0.00                 0.0
# 26520      1.0      285.359                0.00                 0.0
# 28853      1.0      286.670                0.00                 0.0
# 29713      1.0      293.710                0.00                 0.0
# 30934      1.0      289.890                0.00                 0.0
# 31198      1.0      295.940                0.00                 0.0
# 32034      1.0      285.420                0.00                 0.0
# 32800      1.0      262.680                0.00                 0.0
# 33110      1.0      272.040                0.00                 0.0
# 33874      1.0      258.750                0.00                 0.0
# 34042      1.0      249.560                0.00                 0.0
# 34378      1.0      263.540                0.00                 0.0
# 35216      1.0      271.130                0.00                 0.0
# 37557      1.0      300.287                0.00                 0.0
# 72         1.0      298.350                0.00                 0.0
# 1272       1.0      289.520                0.00                 0.0
# 1536       1.0      292.730                0.25                 0.0
#
#        Cloud_Cover             Weather         Weather_Desc      TimeStamp  \
# 126             20        Cloudy skies     Scattered clouds  08/10/08 0:00
# 926             87         Clear skies          Clear skies  12/11/08 0:00
# 1164            21           Light fog             Fine fog  22/11/08 0:00
# 1938            90        Cloudy skies     Full cloud cover  25/12/08 0:00
# 2103            59        Cloudy skies    Fragmented clouds  01/01/09 0:00
# 3066            21        Cloudy skies     Scattered clouds  18/02/09 0:00
# 5236            90        Cloudy skies     Full cloud cover  27/05/09 0:00
# 6075             1         Clear skies          Clear skies  04/07/09 0:00
# 7178            12        Cloudy skies     Scattered clouds  22/08/09 0:00
# 7340             0         Clear skies          Clear skies  02/09/09 0:00
# 7966             0         Clear skies          Clear skies  14/10/09 0:00
# 8236            64        Cloudy skies    Fragmented clouds  11/11/09 0:00
# 8627            64        Cloudy skies    Fragmented clouds  28/11/09 0:00
# 9238            64            Rainfall            Soft rain  25/12/09 0:00
# 9397            91        Cloudy skies     Full cloud cover  01/01/10 0:00
# 9821            64        Cloudy skies    Fragmented clouds  20/01/10 0:00
# 10484           90        Cloudy skies     Full cloud cover  17/02/10 0:00
# 12706           40        Cloudy skies  Partly cloudy skies  26/05/10 0:00
# 14094            1         Clear skies          Clear skies  03/07/11 0:00
# 15406            1         Clear skies          Clear skies  27/08/11 0:00
# 15643           91        Cloudy skies     Full cloud cover  07/09/11 0:00
# 16395            1         Clear skies          Clear skies  12/10/11 0:00
# 16788           75        Cloudy skies    Fragmented clouds  11/11/11 0:00
# 16986           90           Light fog             Fine fog  26/11/11 0:00
# 17366           91            Snowfall             Flurries  25/12/11 0:00
# 17491           90  Airborne particles            Smoky air  01/01/12 0:00
# 18231           90           Light fog             Fine fog  15/02/12 0:00
# 20212            2           Light fog             Fine fog  30/05/12 0:00
# 21039            1         Clear skies          Clear skies  04/07/12 0:00
# 22280            1         Clear skies          Clear skies  25/08/12 0:00
# 22541           90            Rainfall          Steady rain  05/09/12 0:00
# 23372            0         Clear skies          Clear skies  10/10/12 0:00
# 24123            1         Clear skies          Clear skies  11/11/12 0:00
# 24435           76           Light fog             Fine fog  24/11/12 0:00
# 25185           90            Rainfall            Soft rain  26/12/12 0:00
# 25353           90            Snowfall             Flurries  02/01/13 0:00
# 25689            1           Light fog             Fine fog  16/01/13 0:00
# 26520           69        Cloudy skies    Fragmented clouds  20/02/13 0:00
# 28853           40        Cloudy skies  Partly cloudy skies  29/05/13 0:00
# 29713            1         Clear skies          Clear skies  04/07/13 0:00
# 30934           90            Rainfall            Soft rain  24/08/13 0:00
# 31198            1         Clear skies          Clear skies  04/09/13 0:00
# 32034            1         Clear skies          Clear skies  09/10/13 0:00
# 32800            1         Clear skies          Clear skies  10/11/13 0:00
# 33110            1         Clear skies          Clear skies  23/11/13 0:00
# 33874            1         Clear skies          Clear skies  25/12/13 0:00
# 34042            2         Clear skies          Clear skies  01/01/14 0:00
# 34378           90            Snowfall             Flurries  15/01/14 0:00
# 35216           20        Cloudy skies     Scattered clouds  19/02/14 0:00
# 37557           24        Cloudy skies     Scattered clouds  28/05/14 0:00
# 72               1           Light fog             Fine fog  04/07/14 0:00
# 1272             1         Clear skies          Clear skies  23/08/14 0:00
# 1536             1            Rainfall            Soft rain  03/09/14 0:00
#
#            Date  Traffic_Vol
# 126    08/10/08        462.0
# 926    12/11/08       1004.0
# 1164   22/11/08        921.0
# 1938   25/12/08        810.0
# 2103   01/01/09       1442.0
# 3066   18/02/09        562.0
# 5236   27/05/09        869.0
# 6075   04/07/09       1066.0
# 7178   22/08/09        665.0
# 7340   02/09/09       1044.0
# 7966   14/10/09        617.0
# 8236   11/11/09        515.0
# 8627   28/11/09        935.0
# 9238   25/12/09        718.0
# 9397   01/01/10       1403.0
# 9821   20/01/10        488.0
# 10484  17/02/10        585.0
# 12706  26/05/10        972.0
# 14094  03/07/11        968.0
# 15406  27/08/11        615.0
# 15643  07/09/11        977.0
# 16395  12/10/11        501.0
# 16788  11/11/11        565.0
# 16986  26/11/11        842.0
# 17366  25/12/11        899.0
# 17491  01/01/12       1517.0
# 18231  15/02/12        790.0
# 20212  30/05/12       1090.0
# 21039  04/07/12       1123.0
# 22280  25/08/12        665.0
# 22541  05/09/12       1071.0
# 23372  10/10/12        493.0
# 24123  11/11/12        575.0
# 24435  24/11/12        764.0
# 25185  26/12/12        735.0
# 25353  02/01/13        801.0
# 25689  16/01/13        703.0
# 26520  20/02/13        638.0
# 28853  29/05/13       1539.0
# 29713  04/07/13       1235.0
# 30934  24/08/13        660.0
# 31198  04/09/13       1027.0
# 32034  09/10/13        551.0
# 32800  10/11/13        813.0
# 33110  23/11/13       1328.0
# 33874  25/12/13       1099.0
# 34042  01/01/14       1488.0
# 34378  15/01/14        607.0
# 35216  19/02/14        632.0
# 37557  28/05/14       1095.0
# 72     04/07/14          NaN
# 1272   23/08/14          NaN
# 1536   03/09/14          NaN

# %%
train['Weather'].value_counts(), test['Weather'].value_counts()
# Out:
# (Weather
#  Cloudy skies          14477
#  Clear skies           12682
#  Rainfall               4204
#  Light fog              2889
#  Snowfall               2297
#  Airborne particles      736
#  Light rain              497
#  Stormy weather          395
#  Dense fog               182
#  Airborne smoke           13
#  Sudden windstorm          1
#  Name: count, dtype: int64,
#  Weather
#  Clear skies           687
#  Cloudy skies          646
#  Rainfall              565
#  Light fog             183
#  Stormy weather         58
#  Airborne particles     30
#  Dense fog              19
#  Light rain             18
#  Airborne smoke          2
#  Name: count, dtype: int64)

# %%
train['Weather_Desc'].value_counts(), test['Weather_Desc'].value_counts()
# Out:
# (Weather_Desc
#  Clear skies                            12682
#  Full cloud cover                        4947
#  Fragmented clouds                       4455
#  Partly cloudy skies                     3232
#  Fine fog                                2889
#  Soft rain                               2530
#  Scattered clouds                        1843
#  Flurries                                1588
#  Steady rain                             1182
#  Smoky air                                736
#  Deep snow                                500
#  Intense rainfall                         365
#  Mild drizzle                             345
#  Approaching thunderstorm                 290
#  Snowfall                                 192
#  Dense fog                                182
#  Light rain                               135
#  Nearby rain showers                       98
#  Stormy weather                            53
#  Storm with mild rain                      21
#  Torrential downpour                       18
#  Strong drizzle                            17
#  Severe storm with heavy rain              13
#  Airborne smoke                            13
#  Scattered snowflakes                      11
#  Gentle rain shower                        10
#  Approaching thunderstorm with rain         9
#  Storm with rain                            5
#  Storm with a light sprinkle                3
#  Drizzle mixed with snow                    3
#  Icy rain                                   3
#  Sudden windstorm                           1
#  Ice rain                                   1
#  Nearby thunderstorm with light rain        1
#  Name: count, dtype: int64,
#  Weather_Desc
#  Clear skies                     687
#  Soft rain                       301
#  Partly cloudy skies             219
#  Steady rain                     197
#  Fragmented clouds               195
#  Fine fog                        183
#  Full cloud cover                125
#  Scattered clouds                107
#  Approaching thunderstorm         49
#  Intense rainfall                 43
#  Smoky air                        30
#  Nearby rain showers              22
#  Dense fog                        19
#  Mild drizzle                     15
#  Stormy weather                    6
#  Light rain                        3
#  Storm with mild rain              2
#  Airborne smoke                    2
#  Gentle rain shower                2
#  Severe storm with heavy rain      1
#  Name: count, dtype: int64)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40581 entries, 0 to 2207
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Holiday             53 non-null     float64
#  1   Temperature         40581 non-null  float64
#  2   Rainfall_last_hour  40581 non-null  float64
#  3   Snowfall_last_hour  40581 non-null  float64
#  4   Cloud_Cover         40581 non-null  int64
#  5   Weather             40581 non-null  object
#  6   Weather_Desc        40581 non-null  object
#  7   TimeStamp           40581 non-null  object
#  8   Date                40581 non-null  object
#  9   Traffic_Vol         38373 non-null  float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# combined['Holiday'] = combined['Holiday'].fillna(0.0)

# %%
weather_mapping = {
    'Clear skies': 'Clear skies',
    'Cloudy skies': 'Cloudy skies',
    'Rainfall': 'Rain',
    'Light rain': 'Rain',
    'Stormy weather': 'Rain',
    'Snowfall': 'Snow',
    'Airborne particles': 'Fog',
    'Light fog': 'Fog',
    'Dense fog': 'Fog',
    'Airborne smoke': 'Fog',
    'Sudden windstorm': 'Other'
}

# %%
weather_desc_mapping = {
    'Clear skies': 'Clear skies',
    'Full cloud cover': 'Cloudy skies',
    'Fragmented clouds': 'Cloudy skies',
    'Partly cloudy skies': 'Cloudy skies',
    'Scattered clouds': 'Cloudy skies',
    'Fine fog': 'Fog',
    'Dense fog': 'Fog',
    'Smoky air': 'Fog',
    'Soft rain': 'Rain',
    'Steady rain': 'Rain',
    'Intense rainfall': 'Rain',
    'Mild drizzle': 'Rain',
    'Stormy weather': 'Rain',
    'Approaching thunderstorm': 'Rain',
    'Snowfall': 'Snow',
    'Flurries': 'Snow',
    'Deep snow': 'Snow',
    'Other': 'Other'
}

# %%
combined['Weather'] = combined['Weather'].map(weather_mapping).fillna('Other')

# %%
combined['Weather_Desc'] = combined['Weather_Desc'].map(weather_desc_mapping).fillna('Other')

# %%
combined['Weather'].value_counts(), combined['Weather_Desc'].value_counts()
# Out:
# (Weather
#  Cloudy skies    15123
#  Clear skies     13369
#  Rain             5737
#  Fog              4054
#  Snow             2297
#  Other               1
#  Name: count, dtype: int64,
#  Weather_Desc
#  Cloudy skies    15123
#  Clear skies     13369
#  Rain             5376
#  Fog              4039
#  Snow             2280
#  Other             394
#  Name: count, dtype: int64)

# %%
combined['TimeStamp'] = pd.to_datetime(combined['TimeStamp'], format='%d/%m/%y %H:%M')

# %%
combined['Hour'] = combined['TimeStamp'].dt.hour
combined['Day'] = combined['TimeStamp'].dt.day
combined['Month'] = combined['TimeStamp'].dt.month
combined['Day_of_week'] = combined['TimeStamp'].dt.dayofweek

# %%
combined = combined.drop(columns=['TimeStamp', 'Date', 'Holiday'])

# %%
le = LabelEncoder()

x = ['Weather', 'Weather_Desc']
for i in x:
    combined[i] = le.fit_transform(combined[i])

# %%
combined.head()
# Out:
#    Temperature  Rainfall_last_hour  Snowfall_last_hour  Cloud_Cover  Weather  \
# 0       289.28                 0.0                 0.0           40        1
# 1       290.26                 0.0                 0.0           75        1
# 2       290.28                 0.0                 0.0           90        1
# 3       290.33                 0.0                 0.0           90        1
# 4       292.14                 0.0                 0.0           75        1
#
#    Weather_Desc  Traffic_Vol  Hour  Day  Month  Day_of_week
# 0             1       5555.0     9    2     10            3
# 1             1       4525.0    10    2     10            3
# 2             1       4772.0    11    2     10            3
# 3             1       5031.0    12    2     10            3
# 4             1       4928.0    13    2     10            3

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40581 entries, 0 to 2207
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Temperature         40581 non-null  float64
#  1   Rainfall_last_hour  40581 non-null  float64
#  2   Snowfall_last_hour  40581 non-null  float64
#  3   Cloud_Cover         40581 non-null  int64
#  4   Weather             40581 non-null  int32
#  5   Weather_Desc        40581 non-null  int32
#  6   Traffic_Vol         38373 non-null  float64
#  7   Hour                40581 non-null  int32
#  8   Day                 40581 non-null  int32
#  9   Month               40581 non-null  int32
#  10  Day_of_week         40581 non-null  int32
# dtypes: float64(4), int32(6), int64(1)
# memory usage: 2.8 MB

# %%
newtrain = combined.iloc[0:38373, :]
newtest = combined.iloc[38373: , :]
newtest = newtest.drop('Traffic_Vol', axis = 1)

# %%
newtrain.shape, newtest.shape
# Out:
# ((38373, 11), (2208, 10))

# %%
x = newtrain.drop('Traffic_Vol', axis = 1)
y = newtrain['Traffic_Vol']

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state =  42)

# %%
models = {'Linear Regression': LinearRegression(), 'Random Forest' : RandomForestRegressor(), 'Bagging' : BaggingRegressor(),
          'Extra Tree': ExtraTreesRegressor(), 'LightGBM': LGBMRegressor(), 'Gradient Boosting': GradientBoostingRegressor(),
          'Adaboost': AdaBoostRegressor(), 'XGB': XGBRegressor() }

# %%
def evaluate_models(x_train, x_test, y_train, y_test, models):
    results = {}
    for name, model in models.items():
        predictions = model.fit(x_train, y_train).predict(x_test)
        rmse = np.sqrt(mean_squared_error(y_test, predictions))
        results[name] = rmse
    return results

# %%
result = evaluate_models(x_train, x_test, y_train, y_test, models)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002487 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 673
# [LightGBM] [Info] Number of data points in the train set: 30698, number of used features: 10
# [LightGBM] [Info] Start training from score 3296.553033

# %%
best_model_name = min(result, key = result.get)
best_model = models[best_model_name]

# %%
print(f"Best model is {best_model_name} with rmse {result[best_model_name]}")
# Out:
# Best model is LightGBM with rmse 364.5691005990524

# %%
y_pred = best_model.fit(x_train, y_train).predict(x_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 673
# [LightGBM] [Info] Number of data points in the train set: 30698, number of used features: 10
# [LightGBM] [Info] Start training from score 3296.553033

# %%
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 364.5691005990524

# %%
x_train = newtrain.drop('Traffic_Vol', axis = 1)
y_train = newtrain['Traffic_Vol']
x_test = newtest
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
y_pred = best_model.fit(x_train, y_train).predict(x_test)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002918 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 678
# [LightGBM] [Info] Number of data points in the train set: 38373, number of used features: 10
# [LightGBM] [Info] Start training from score 3293.947567

# %%
solution = pd.DataFrame({'Traffic_Vol' : y_pred})
solution.head()
# Out:
#    Traffic_Vol
# 0  1398.393962
# 1   872.274894
# 2   674.889647
# 3   476.196086
# 4   475.224475

# %%
solution.to_csv('Solution.csv', index = False)
